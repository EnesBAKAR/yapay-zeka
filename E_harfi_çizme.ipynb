# %% [markdown]
# <a href="https://colab.research.google.com/github/EnesBAKAR/yapay-zeka/blob/main/E_harfi_%C3%A7izme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([2,1,1,2,1,1,2])
y=np.array([60,60,35,35,35,10,10])
plt.plot(x,y)
plt.title("Sonuçlar")
plt.show()
